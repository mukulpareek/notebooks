# %%
import pandas as pd

# %%
x = pd.read_csv('ttrss_entries.csv')

# %%
x
# Out:
#       id                                              title  \
# 0      1  Problems in manufacturing the coronavirus test...
# 1      2  Congressman calls for SEC investigation into l...
# 2      3           Trump 'champing at the bit' to reopen US
# 3      4        Watch: Beachgoers swarm the sand in Florida
# 4      5  Prediction: Doctor discusses when states could...
# ..   ...                                                ...
# 165  166  National Youth Orchestra's Ode to Joy across G...
# 166  167  Coronavirus: 'I'm scared my dreams of becoming...
# 167  168  Coronavirus: The businesses crowdfunding to su...
# 168  169        ‘Coronavirus has robbed me of my dream job’
# 169  170  Coronavirus: Pregnant nurse dies but baby 'wel...
#
#                                               guid  \
# 0    SHA1:89b2746c357f94466893de557d3b2ef51dbf3eaf
# 1    SHA1:da02c50cb3699700a50890ebf6cce35fcc08c9ab
# 2    SHA1:331e188f32f68adb5d31ceaaccd8083779259639
# ...

# %%
# x['content'].str.find('strangest')!=-1
x[x['content'].str.contains('architecture')]
# Out:
#     id                                      title  \
# 65  66  California's strangest roadside buildings
#
#                                              guid  \
# 65  SHA1:2e12ab8fdadf676c55b7acf1961546f1f33a8d92
#
#                                                  link              updated  \
# 65  http://rss.cnn.com/~r/rss/cnn_topstories/~3/nK...  2020-04-13 13:18:59
#
#                                               content  \
# 65  Roadside architecture, a trend that had its he...
#
#                                 content_hash  cached_content  no_orig_date  \
# 65  ef3f0ab21a2c8b0acc385081f6d762ef6fe6aa57             NaN             0
#
#            date_entered         date_updated  num_comments  plugin_data lang  \
# 65  2020-04-18 20:48:00  2020-04-18 21:49:26             0          NaN   en
#
#     comments author
# 65       NaN    NaN

# %%
x.iloc[65]['content']
# Out:
# "Roadside architecture, a trend that had its heyday in 1930s Southern California, was once dismissed by critics. But now it's enjoying a resurgence. A giant doughnut, a shoe-shaped shoe repair shop, an ice cream parlor that looks like a massive owl and a hot dog as big as a firetruck: few places in the world have as many crazy buildings as Southern Calfornia, and these are just a few of the eye-grabbing oddities that pepper the streets of the Greater Los Angeles area.\n    \n"

# %%
from bs4 import BeautifulSoup
cleantext = BeautifulSoup(article.html, "lxml").text

# %%
import newspaper
print(newspaper.fulltext(article.html))
# Out:
# Image copyright Kate O'Loughlin
#
# “Coronavirus has definitely cost me, at least temporarily, my dream job.”
#
# For Kate O'Loughlin, a 24-year-old student from Dublin, the summer after graduation looked exciting. She had internships and job interviews lined up at music labels and events companies that she had been trying to break into.
#
# But then coronavirus hit. Offers were withdrawn one by one.
#
# “My heart was set on starting out, so having that taken away from me was absolutely gutting," she says.
#
# "I was hoping to get some experience to really kickstart my career in the music industry and climb up the ladder.”
#
# Kate has also put off plans to study a master's degree at either London or Belfast over money worries. Coronavirus means a lot of her paid work has been pushed back.
#
# “It’s quite possibly robbed me of my dreams for 2020, but obviously everyone’s health has to come first," she says. "I’m trying to remain as positive as I can.”
#
# Scaling down
#
# ...

# %%
x['title'][0]
# Out:
# 'Problems in manufacturing the coronavirus test caused weeks of delays, multiple health officials say'

# %%
import re

def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>')
  cleantext = re.sub(cleanr, '', raw_html)
  return cleantext

# %%
x['content'] = x['content'].apply(cleanhtml)

# %%
# !pip install newspaper3k

# %%
# https://newspaper.readthedocs.io/en/latest/
from newspaper import Article
url = 'https://www.bbc.co.uk/news/business-52152606'
article = Article(url)
article.download()

# %%
article.parse()

# %%
article.text
# Out:
# 'Image copyright Kate O\'Loughlin\n\n“Coronavirus has definitely cost me, at least temporarily, my dream job.”\n\nFor Kate O\'Loughlin, a 24-year-old student from Dublin, the summer after graduation looked exciting. She had internships and job interviews lined up at music labels and events companies that she had been trying to break into.\n\nBut then coronavirus hit. Offers were withdrawn one by one.\n\n“My heart was set on starting out, so having that taken away from me was absolutely gutting," she says.\n\n"I was hoping to get some experience to really kickstart my career in the music industry and climb up the ladder.”\n\nKate has also put off plans to study a master\'s degree at either London or Belfast over money worries. Coronavirus means a lot of her paid work has been pushed back.\n\n“It’s quite possibly robbed me of my dreams for 2020, but obviously everyone’s health has to come first," she says. "I’m trying to remain as positive as I can.”\n\nScaling down\n\nJust a couple of
# ...

# %%
import nltk
nltk.download('punkt')
article.nlp()
article.keywords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# ['young',
#  'future',
#  'coronavirus',
#  'kate',
#  'student',
#  'interviews',
#  'work',
#  'youre',
#  'job',
#  'dream',
#  'robbed',
#  'experience']

# %%
print(article.summary)
# Out:
# She had internships and job interviews lined up at music labels and events companies that she had been trying to break into.
# “It’s quite possibly robbed me of my dreams for 2020, but obviously everyone’s health has to come first," she says.
# More than two-thirds of those 124 companies surveyed were cancelling work experience.
# Rebecca, a 20-year-old communications student at Glasgow Caledonian University, lost her first work experience opportunity because of the outbreak.
# “I was really excited for my first proper work experience and was hoping to build up my CV,” she says, adding she was "gutted" when the opportunity vanished.
